# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split,KFold,cross_val_score
import os
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
os.chdir("D:/Machine Learning/Datasets/Datasets")

# %%
df = pd.read_csv('Concrete_Data.csv')
print(df.shape)
df.head()
# Out:
# (1030, 9)
#    Cement  Blast  Fly  Water  Superplasticizer  Coarse   Fine  Age  Strength
# 0   540.0    0.0  0.0  162.0               2.5  1040.0  676.0   28     79.99
# 1   540.0    0.0  0.0  162.0               2.5  1055.0  676.0   28     61.89
# 2   332.5  142.5  0.0  228.0               0.0   932.0  594.0  270     40.27
# 3   332.5  142.5  0.0  228.0               0.0   932.0  594.0  365     41.05
# 4   198.6  132.4  0.0  192.0               0.0   978.4  825.5  360     44.30

# %%
#dum_df = pd.get_dummies(df,drop_first=True)

# %% [markdown]
# #### Trying for linear, Ridge and  Lasso and Elastic Net

# %%
### for the linear Regression

x = df.drop(['Strength'],axis=1)  # independents columns 
y = df['Strength'] # target 

# setting the k fold cross validation 
kfold = KFold(n_splits=5,random_state=24,shuffle=True)

lr = LinearRegression()

results = cross_val_score(lr,x,y,cv=kfold)

print("r2 squares for 5 fold cross validation is :",results)
print("")
print("Mean of r2 squares for the k fold cros validation ",results.mean())
# Out:
# r2 squares for 5 fold cross validation is : [0.54197748 0.62408005 0.63130419 0.59888932 0.63678175]
#
# Mean of r2 squares for the k fold cros validation  0.6066065590942402

# %%
### for the Ridge Regression
from sklearn.linear_model import Ridge

x = df.drop(['Strength'],axis=1)  # independents columns 
y = df['Strength'] # target  

# setting the k fold cross validation 
kfold = KFold(n_splits=5,random_state=24,shuffle=True)


rd = Ridge()

results = cross_val_score(rd,x,y,cv=kfold)

print("r2 squares for 5 fold cross validation is :",results)
print("")
print("Mean of r2 squares for the k fold cros validation ",results.mean())
# Out:
# r2 squares for 5 fold cross validation is : [0.54197719 0.62408021 0.6313042  0.59888929 0.63678192]
#
# Mean of r2 squares for the k fold cros validation  0.6066065614459983

# %%
### for the Lasso Regression
from sklearn.linear_model import Lasso

x = df.drop(['Strength'],axis=1)  # independents columns 
y = df['Strength'] # target  

# setting the k fold cross validation 
kfold = KFold(n_splits=5,random_state=24,shuffle=True)


ls = Lasso()

results = cross_val_score(ls,x,y,cv=kfold)

print("r2 squares for 5 fold cross validation is :",results)
print("")
print("Mean of r2 squares for the k fold cros validation ",results.mean())
# Out:
# r2 squares for 5 fold cross validation is : [0.54146417 0.62434671 0.63093559 0.59768193 0.63708517]
#
# Mean of r2 squares for the k fold cros validation  0.606302714816816

# %%
### for the Elastic Regression
from sklearn.linear_model import ElasticNet

x = df.drop(['Strength'],axis=1)  # independents columns 
y = df['Strength'] # target 

# setting the k fold cross validation 
kfold = KFold(n_splits=5,random_state=24,shuffle=True)


el = ElasticNet()

results = cross_val_score(el,x,y,cv=kfold)

print("r2 squares for 5 fold cross validation is :",results)
print("")
print("Mean of r2 squares for the k fold cros validation ",results.mean())
# Out:
# r2 squares for 5 fold cross validation is : [0.54165955 0.62429071 0.6311365  0.59832447 0.63701585]
#
# Mean of r2 squares for the k fold cros validation  0.6064854161222563

# %%
# k fold is always better than the train_test_split

# %% [markdown]
# ### Ridge regression using kfold

# %%
### for the Ridge Regression
from sklearn.linear_model import Ridge

x = df.drop(['Strength'],axis=1)  # independents columns 
y = df['Strength'] # target 

# setting the k fold cross validation 
kfold = KFold(n_splits=5,random_state=24,shuffle=True)

scores=[]
alphas = np.arange(0,10,0.25)
for i in alphas:
    rd = Ridge(alpha=i)
    results = cross_val_score(rd,x,y,cv=kfold)
    scores.append(results.mean())

i_max = np.argmax(scores)
print('Best Alpha : ',alphas[i_max])
print('Best Score : ', scores[i_max])
# Out:
# Best Alpha :  9.75
# Best Score :  0.6066065796230419

# %% [markdown]
# ### Lasso Regression using kfold

# %%
### for the Lasso Regression
from sklearn.linear_model import Lasso

x = df.drop(['Strength'],axis=1)  # independents columns 
y = df['Strength'] # target 

# setting the k fold cross validation 
kfold = KFold(n_splits=5,random_state=24,shuffle=True)
ls = Lasso()

scores=[]
alphas = np.arange(0,10,0.25)
for i in alphas:
    rd = Lasso(alpha=i)
    results = cross_val_score(rd,x,y,cv=kfold)
    scores.append(results.mean())

i_max = np.argmax(scores)
print('Best Alpha : ',alphas[i_max])
print('Best Score : ', scores[i_max])
# Out:
# Best Alpha :  0.0
# Best Score :  0.6066065590942402

# %% [markdown]
# ### Elastic Net regression using kfold

# %%
### for the Elastic Regression
from sklearn.linear_model import ElasticNet

x = df.drop(['Strength'],axis=1)  # independents columns 
y = df['Strength'] # target 

# setting the k fold cross validation 
kfold = KFold(n_splits=5,random_state=24,shuffle=True)

# correct way  

alphas = np.arange(0,10,0.25)
l1 = np.arange(0, 1,0.1)
scores = []
for i in alphas:
    for j in l1:
        el = ElasticNet(alpha=i, l1_ratio=j)
        results = cross_val_score(el,x,y,cv=kfold)
        scores.append([i,j,results.mean()])
        
pd_scores = pd.DataFrame(scores, columns=['alpha','L1-ratio','r2'])
pd_scores.sort_values(by='r2',ascending=False).iloc[0]
# Out:
# alpha       0.000000
# L1-ratio    0.000000
# r2          0.606607
# Name: 0, dtype: float64

# %% [markdown]
# Ridge
# Best Alpha :  4.0
# Best Score :  0.6577381120548891
#
# Lasso
# Best Alpha :  9.5
# Best Score :  0.657087435238261
#
# Elastic Net
# alpha       0.000000
# L1-ratio    0.000000
# r2          0.657081
# Name: 0, dtype: float64

# %% [markdown]
# ### finding best score and r2 without loop

# %%
from sklearn.model_selection import GridSearchCV

# %%
## Ridge Regression

alphas = np.arange(0,10,0.25)
params = {'alpha':alphas}
ridge = Ridge()
kfold = KFold(n_splits=5, shuffle=True, random_state=24)
gcv_r= GridSearchCV(ridge, param_grid=params, cv=kfold)
gcv_r.fit(x,y)
print(gcv_r.best_params_)
print(gcv_r.best_score_)
# Out:
# {'alpha': 9.75}
# 0.6066065796230419

# %%
## Ridge Regression with mean square error

alphas = np.arange(0,10,0.25)
params = {'alpha':alphas}
ridge = Ridge()
kfold = KFold(n_splits=5, shuffle=True, random_state=24)
gcv_r= GridSearchCV(ridge, param_grid=params, cv=kfold, scoring='neg_mean_squared_error')
gcv_r.fit(x,y)
print(gcv_r.best_params_)
print(gcv_r.best_score_)

pdcv = pd.DataFrame(gcv_r.cv_results_)
# Out:
# {'alpha': 9.75}
# -109.00383749240787

# %%
## lasso Regression

alphas = np.arange(0,10,0.25)
params = {'alpha':alphas}
lasso = Lasso()
kfold = KFold(n_splits=5, shuffle=True, random_state=24)
gcv_l= GridSearchCV(lasso, param_grid=params, cv=kfold)
gcv_l.fit(x,y)
print(gcv_l.best_params_)
print(gcv_l.best_score_)
# Out:
# {'alpha': 0.0}
# 0.6066065590942402

# %%
## Elastic Net Regression

alphas = np.arange(0,10,0.25)
l1 = np.arange(0, 1,0.1)

params = {'alpha':alphas,'l1_ratio':l1}
el = ElasticNet()
kfold = KFold(n_splits=5, shuffle=True, random_state=24)
gcv_el = GridSearchCV(el, param_grid=params, cv=kfold)
gcv_el.fit(x,y)
print(gcv_el.best_params_)
print(gcv_el.best_score_)
# Out:
# {'alpha': 0.0, 'l1_ratio': 0.0}
# 0.6066065590942402

# %%
# verify best test score and params
pd_cv = pd.DataFrame(gcv.cv_results_)
pd_cv.to_csv("D:/Machine Learning/Datasets/best_score_results2.csv")

# %% [markdown]
# ## For unlabelled data => test concrete

# %%
## Ridge Regression

alphas = np.arange(0,10,0.25)
params = {'alpha':alphas}
ridge = Ridge()
kfold = KFold(n_splits=5, shuffle=True, random_state=24)
gcv_r= GridSearchCV(ridge, param_grid=params, cv=kfold)
gcv_r.fit(x,y)
best_model = gcv_r.best_estimator_

tst = pd.read_csv("testConcrete.csv") ## reading the test data which is unlabel

pred_strength = best_model.predict(tst) # appling best_model object to the tst for predictions
print(pred_strength)
# Out:
# [68.73876931 31.78900645 19.49352047 46.84974452 58.04413155 16.09636391
#  50.35237168 80.31308633 31.13698396 41.57074962 43.44491821 60.77326762
#  52.3709778  15.38705846]

# %%
pdcv
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_alpha  \
# 0        0.003204  4.044462e-04         0.001799    3.998520e-04         0.0
# 1        0.001597  4.862951e-04         0.001598    4.887944e-04        0.25
# 2        0.001999  2.861023e-07         0.001199    4.000664e-04         0.5
# 3        0.001999  5.722046e-07         0.001399    4.896486e-04        0.75
# 4        0.001802  4.011652e-04         0.001399    4.936050e-04         1.0
# 5        0.002396  4.913055e-04         0.001598    4.907209e-04        1.25
# 6        0.002000  2.243670e-06         0.080549    1.591105e-01         1.5
# 7        0.001999  6.321081e-04         0.001199    3.998280e-04        1.75
# 8        0.001799  3.998518e-04         0.001399    4.895120e-04         2.0
# 9        0.001799  3.997564e-04         0.001399    4.896483e-04        2.25
# 10       0.001599  4.896288e-04         0.001399    4.893952e-04         2.5
# 11       0.001799  3.996849e-04         0.001199    3.996134e-04        2.75
# 12       0.001799  3.996849e-04         0.001199    3.996849e-04         3.0
# 13       0.001799  3.997805e-04         0.001399    4.896094e-04        3.25
# 14       0.001799  3.996372e-04         0.001399    4.895510e-04         3.5
# 15       0.001799  3.998280e-04         0.001199    3.998042e-04        3.75
# 16       0.001799  3.997326e-04         0.001399    4.895316e-04         4.0
# 17       0.001799  3.996611e-04         0.001399    4.895510e-04        4.25
# 18       0.001999  2.336015e-07         0.001199    3.997804e-04         4.5
# 19       0.001799  3.998280e-04         0.001199    3.997565e-04        4.75
# 20       0.001799  3.996134e-04         0.001399    4.895510e-04         5.0
# 21       0.001799  3.996849e-04         0.001400    4.894926e-04        5.25
# 22       0.001799  3.996134e-04         0.001399    4.894536e-04         5.5
# 23       0.001799  3.996611e-04         0.001399    4.894537e-04        5.75
# 24       0.001800  4.006288e-04         0.001398    4.907287e-04         6.0
# 25       0.001799  3.997803e-04         0.001399    4.894537e-04        6.25
# 26       0.001999  4.672031e-07         0.001199    3.997567e-04         6.5
# 27       0.001799  3.997803e-04         0.001399    4.895510e-04        6.75
# 28       0.002199  3.999950e-04         0.001399    4.897458e-04         7.0
# 29       0.001998  3.162980e-07         0.001000    4.156970e-07        7.25
# 30       0.001799  3.996611e-04         0.001199    3.996611e-04         7.5
# 31       0.001999  8.937760e-04         0.001799    3.997565e-04        7.75
# 32       0.002798  3.995897e-04         0.001799    3.997805e-04         8.0
# 33       0.002398  4.895705e-04         0.001999    1.507891e-07        8.25
# 34       0.002398  4.895706e-04         0.001999    6.468134e-07         8.5
# 35       0.002198  7.477548e-04         0.001399    4.894927e-04        8.75
# 36       0.001799  3.998519e-04         0.001399    4.895120e-04         9.0
# 37       0.001999  1.168008e-07         0.001199    3.997326e-04        9.25
# 38       0.001799  3.997803e-04         0.001399    4.896872e-04         9.5
# 39       0.001599  4.894537e-04         0.001399    4.893369e-04        9.75
#
#              params  split0_test_score  split1_test_score  split2_test_score  \
# 0    {'alpha': 0.0}        -115.375737         -98.960092        -114.421495
# 1   {'alpha': 0.25}        -115.375756         -98.960082        -114.421495
# 2    {'alpha': 0.5}        -115.375774         -98.960071        -114.421494
# 3   {'alpha': 0.75}        -115.375792         -98.960061        -114.421494
# 4    {'alpha': 1.0}        -115.375811         -98.960050        -114.421493
# 5   {'alpha': 1.25}        -115.375829         -98.960039        -114.421493
# 6    {'alpha': 1.5}        -115.375848         -98.960029        -114.421493
# 7   {'alpha': 1.75}        -115.375866         -98.960018        -114.421492
# 8    {'alpha': 2.0}        -115.375884         -98.960008        -114.421492
# 9   {'alpha': 2.25}        -115.375903         -98.959997        -114.421492
# 10   {'alpha': 2.5}        -115.375921         -98.959987        -114.421491
# 11  {'alpha': 2.75}        -115.375940         -98.959976        -114.421491
# 12   {'alpha': 3.0}        -115.375958         -98.959965        -114.421490
# 13  {'alpha': 3.25}        -115.375976         -98.959955        -114.421490
# 14   {'alpha': 3.5}        -115.375995         -98.959944        -114.421490
# 15  {'alpha': 3.75}        -115.376013         -98.959934        -114.421489
# 16   {'alpha': 4.0}        -115.376032         -98.959923        -114.421489
# 17  {'alpha': 4.25}        -115.376050         -98.959913        -114.421489
# 18   {'alpha': 4.5}        -115.376069         -98.959902        -114.421488
# 19  {'alpha': 4.75}        -115.376087         -98.959891        -114.421488
# 20   {'alpha': 5.0}        -115.376105         -98.959881        -114.421487
# 21  {'alpha': 5.25}        -115.376124         -98.959870        -114.421487
# 22   {'alpha': 5.5}        -115.376142         -98.959860        -114.421487
# 23  {'alpha': 5.75}        -115.376161         -98.959849        -114.421486
# 24   {'alpha': 6.0}        -115.376179         -98.959839        -114.421486
# 25  {'alpha': 6.25}        -115.376197         -98.959828        -114.421486
# 26   {'alpha': 6.5}        -115.376216         -98.959818        -114.421485
# 27  {'alpha': 6.75}        -115.376234         -98.959807        -114.421485
# 28   {'alpha': 7.0}        -115.376253         -98.959797        -114.421485
# 29  {'alpha': 7.25}        -115.376271         -98.959786        -114.421484
# 30   {'alpha': 7.5}        -115.376289         -98.959775        -114.421484
# 31  {'alpha': 7.75}        -115.376308         -98.959765        -114.421483
# 32   {'alpha': 8.0}        -115.376326         -98.959754        -114.421483
# 33  {'alpha': 8.25}        -115.376345         -98.959744        -114.421483
# 34   {'alpha': 8.5}        -115.376363         -98.959733        -114.421482
# 35  {'alpha': 8.75}        -115.376381         -98.959723        -114.421482
# 36   {'alpha': 9.0}        -115.376400         -98.959712        -114.421482
# 37  {'alpha': 9.25}        -115.376418         -98.959702        -114.421481
# 38   {'alpha': 9.5}        -115.376437         -98.959691        -114.421481
# 39  {'alpha': 9.75}        -115.376455         -98.959681        -114.421481
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0         -112.251372        -104.010586      -109.003856        6.423519
# 1         -112.251374        -104.010574      -109.003856        6.423528
# 2         -112.251376        -104.010562      -109.003855        6.423537
# 3         -112.251377        -104.010550      -109.003855        6.423546
# 4         -112.251379        -104.010538      -109.003854        6.423555
# 5         -112.251381        -104.010526      -109.003854        6.423564
# 6         -112.251383        -104.010514      -109.003853        6.423573
# 7         -112.251385        -104.010502      -109.003853        6.423582
# 8         -112.251387        -104.010490      -109.003852        6.423591
# 9         -112.251389        -104.010478      -109.003852        6.423599
# 10        -112.251391        -104.010467      -109.003851        6.423608
# 11        -112.251393        -104.010455      -109.003851        6.423617
# 12        -112.251395        -104.010443      -109.003850        6.423626
# 13        -112.251397        -104.010431      -109.003850        6.423635
# 14        -112.251399        -104.010419      -109.003849        6.423644
# 15        -112.251401        -104.010407      -109.003849        6.423653
# 16        -112.251403        -104.010395      -109.003848        6.423662
# 17        -112.251405        -104.010383      -109.003848        6.423671
# 18        -112.251407        -104.010371      -109.003847        6.423680
# 19        -112.251409        -104.010359      -109.003847        6.423689
# 20        -112.251411        -104.010347      -109.003846        6.423698
# 21        -112.251413        -104.010336      -109.003846        6.423707
# 22        -112.251415        -104.010324      -109.003846        6.423716
# 23        -112.251417        -104.010312      -109.003845        6.423725
# 24        -112.251419        -104.010300      -109.003845        6.423734
# 25        -112.251421        -104.010288      -109.003844        6.423743
# 26        -112.251423        -104.010276      -109.003844        6.423751
# 27        -112.251425        -104.010264      -109.003843        6.423760
# 28        -112.251427        -104.010252      -109.003843        6.423769
# 29        -112.251429        -104.010241      -109.003842        6.423778
# 30        -112.251431        -104.010229      -109.003842        6.423787
# 31        -112.251433        -104.010217      -109.003841        6.423796
# 32        -112.251435        -104.010205      -109.003841        6.423805
# 33        -112.251437        -104.010193      -109.003840        6.423814
# 34        -112.251439        -104.010181      -109.003840        6.423823
# 35        -112.251441        -104.010169      -109.003839        6.423832
# 36        -112.251443        -104.010157      -109.003839        6.423841
# 37        -112.251445        -104.010146      -109.003838        6.423850
# 38        -112.251447        -104.010134      -109.003838        6.423859
# 39        -112.251449        -104.010122      -109.003837        6.423868
#
#     rank_test_score
# 0                40
# 1                39
# 2                38
# 3                37
# 4                36
# 5                35
# 6                34
# 7                33
# 8                32
# 9                31
# 10               30
# 11               29
# 12               28
# 13               27
# 14               26
# 15               25
# 16               24
# 17               23
# 18               22
# 19               21
# 20               20
# 21               19
# 22               18
# 23               17
# 24               16
# 25               15
# 26               14
# 27               13
# 28               12
# 29               11
# 30               10
# 31                9
# 32                8
# 33                7
# 34                6
# 35                5
# 36                4
# 37                3
# 38                2
# 39                1
