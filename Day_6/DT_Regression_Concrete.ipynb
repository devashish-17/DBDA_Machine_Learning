# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score, train_test_split, StratifiedKFold, GridSearchCV
from sklearn.metrics import confusion_matrix, accuracy_score, log_loss
from sklearn.tree import DecisionTreeRegressor, plot_tree

# %%
df = pd.read_csv('Concrete_Data.csv')
df.head()
# Out:
#    Cement  Blast  Fly  Water  Superplasticizer  Coarse   Fine  Age  Strength
# 0   540.0    0.0  0.0  162.0               2.5  1040.0  676.0   28     79.99
# 1   540.0    0.0  0.0  162.0               2.5  1055.0  676.0   28     61.89
# 2   332.5  142.5  0.0  228.0               0.0   932.0  594.0  270     40.27
# 3   332.5  142.5  0.0  228.0               0.0   932.0  594.0  365     41.05
# 4   198.6  132.4  0.0  192.0               0.0   978.4  825.5  360     44.30

# %%
X = df.drop('Strength', axis=1)
y = df['Strength']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=24)

# %%
dtc = DecisionTreeRegressor(random_state=24, max_depth=2)
dtc.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=2, random_state=24)

# %%
plt.figure(figsize=(10, 8))
plot_tree(dtc, feature_names=X_train.columns, class_names=['0','1'], filled=True)
plt.show()

# %%
params = {"max_depth " : [2,5,7,none],"min_samp0le_split" = :[2,5,7,10,13],"min_sample_leaf" : [1,5,10,13]}
dtr = DecosiopjnTreeRegressior(random_state = 24)
kfold = ffold (n_spli = 5,shuffle = true, random_state = 24)
gcv = gridsearchCV
