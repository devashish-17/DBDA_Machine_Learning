# %%
# pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\dbda\appdata\local\anaconda3\lib\site-packages (2.0.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy in c:\users\dbda\appdata\local\anaconda3\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\dbda\appdata\local\anaconda3\lib\site-packages (from xgboost) (1.11.4)

# %%
from xgboost import XGBClassifier

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold, KFold

# %%
df = pd.read_csv('HR_comma_sep.csv', sep=',')
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.10             0.77               6                   247
# 3                0.92             0.85               5                   259
# 4                0.89             1.00               5                   224
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   5              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# 2     low
# 3     low
# 4     low

# %%
dum_hr = pd.get_dummies(df, drop_first=True)
dum_hr.head(2)
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
#
#    time_spend_company  Work_accident  left  promotion_last_5years  \
# 0                   3              0     1                      0
# 1                   6              0     1                      0
#
#    Department_RandD  Department_accounting  Department_hr  \
# 0             False                  False          False
# 1             False                  False          False
#
#    Department_management  Department_marketing  Department_product_mng  \
# 0                  False                 False                   False
# 1                  False                 False                   False
#
#    Department_sales  Department_support  Department_technical  salary_low  \
# 0              True               False                 False        True
# 1              True               False                 False       False
#
#    salary_medium
# 0          False
# 1           True

# %%
X = dum_hr.drop('left', axis=1)
y = dum_hr['left']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=24)

# %%
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=24)
xgbc = XGBClassifier(random_state=24)

params = {
    'n_estimators': [50,100,150],
    'learning_rate': [0.01, 0.1, 0.3, 0.5],
    'max_depth': [1,3,5,7]
}
gcv = GridSearchCV(xgbc, param_grid=params, cv=kfold, verbose=3, scoring='neg_log_loss')
gcv.fit(X, y)
print(gcv.best_params_)
print(gcv.best_score_)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [CV 1/5] END learning_rate=0.01, max_depth=1, n_estimators=50;, score=-0.467 total time=   0.2s
# [CV 2/5] END learning_rate=0.01, max_depth=1, n_estimators=50;, score=-0.467 total time=   0.0s
# [CV 3/5] END learning_rate=0.01, max_depth=1, n_estimators=50;, score=-0.466 total time=   0.0s
# [CV 4/5] END learning_rate=0.01, max_depth=1, n_estimators=50;, score=-0.468 total time=   0.0s
# [CV 5/5] END learning_rate=0.01, max_depth=1, n_estimators=50;, score=-0.463 total time=   0.0s
# [CV 1/5] END learning_rate=0.01, max_depth=1, n_estimators=100;, score=-0.427 total time=   0.0s
# [CV 2/5] END learning_rate=0.01, max_depth=1, n_estimators=100;, score=-0.426 total time=   0.0s
# [CV 3/5] END learning_rate=0.01, max_depth=1, n_estimators=100;, score=-0.426 total time=   0.0s
# [CV 4/5] END learning_rate=0.01, max_depth=1, n_estimators=100;, score=-0.428 total time=   0.0s
# [CV 5/5] END learning_rate=0.01, max_depth=1, n_estimators=100;, score=-0.421 total time=   0.0s
# [CV 1/5] END learning_rate=0.01, max_depth=1, n_estimators=150;, score=-0.401 total time=   0.0s
# [CV 2/5] END learning_rate=0.01, max_depth=1, n_estimators=150;, score=-0.399 total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=1, n_estimators=150;, score=-0.399 total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=1, n_estimators=150;, score=-0.401 total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=1, n_estimators=150;, score=-0.393 total time=   0.0s
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=50;, score=-0.332 total time=   0.0s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=50;, score=-0.335 total time=   0.0s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=50;, score=-0.333 total time=   0.0s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=50;, score=-0.335 total time=   0.0s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=50;, score=-0.334 total time=   0.0s
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=-0.235 total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=-0.241 total time=   0.0s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=-0.238 total time=   0.0s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=-0.245 total time=   0.0s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=-0.240 total time=   0.0s
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=150;, score=-0.186 total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=150;, score=-0.193 total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=150;, score=-0.190 total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=150;, score=-0.198 total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=150;, score=-0.191 total time=   0.1s
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=50;, score=-0.313 total time=   0.0s
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=50;, score=-0.317 total time=   0.0s
# [CV 3/5] END learning_rate=0.01, max_depth=5, n_estimators=50;, score=-0.313 total time=   0.0s
# [CV 4/5] END learning_rate=0.01, max_depth=5, n_estimators=50;, score=-0.314 total time=   0.0s
# [CV 5/5] END learning_rate=0.01, max_depth=5, n_estimators=50;, score=-0.315 total time=   0.0s
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=-0.207 total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=-0.213 total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=-0.210 total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=-0.214 total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=5, n_estimators=100;, score=-0.211 total time=   0.1s
# [CV 1/5] END learning_rate=0.01, max_depth=5, n_estimators=150;, score=-0.151 total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=5, n_estimators=150;, score=-0.158 total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=5, n_estimators=150;, score=-0.156 total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=5, n_estimators=150;, score=-0.162 total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=5, n_estimators=150;, score=-0.156 total time=   0.1s
# [CV 1/5] END learning_rate=0.01, max_depth=7, n_estimators=50;, score=-0.300 total time=   0.0s
# [CV 2/5] END learning_rate=0.01, max_depth=7, n_estimators=50;, score=-0.303 total time=   0.0s
# [CV 3/5] END learning_rate=0.01, max_depth=7, n_estimators=50;, score=-0.302 total time=   0.0s
# [CV 4/5] END learning_rate=0.01, max_depth=7, n_estimators=50;, score=-0.307 total time=   0.0s
# [CV 5/5] END learning_rate=0.01, max_depth=7, n_estimators=50;, score=-0.303 total time=   0.0s
# [CV 1/5] END learning_rate=0.01, max_depth=7, n_estimators=100;, score=-0.195 total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=7, n_estimators=100;, score=-0.199 total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=7, n_estimators=100;, score=-0.197 total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=7, n_estimators=100;, score=-0.204 total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=7, n_estimators=100;, score=-0.198 total time=   0.1s
# [CV 1/5] END learning_rate=0.01, max_depth=7, n_estimators=150;, score=-0.139 total time=   0.2s
# [CV 2/5] END learning_rate=0.01, max_depth=7, n_estimators=150;, score=-0.144 total time=   0.2s
# [CV 3/5] END learning_rate=0.01, max_depth=7, n_estimators=150;, score=-0.142 total time=   0.2s
# [CV 4/5] END learning_rate=0.01, max_depth=7, n_estimators=150;, score=-0.149 total time=   0.2s
# [CV 5/5] END learning_rate=0.01, max_depth=7, n_estimators=150;, score=-0.143 total time=   0.2s
# [CV 1/5] END learning_rate=0.1, max_depth=1, n_estimators=50;, score=-0.312 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, max_depth=1, n_estimators=50;, score=-0.313 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, max_depth=1, n_estimators=50;, score=-0.314 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, max_depth=1, n_estimators=50;, score=-0.319 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, max_depth=1, n_estimators=50;, score=-0.306 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, max_depth=1, n_estimators=100;, score=-0.263 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, max_depth=1, n_estimators=100;, score=-0.264 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, max_depth=1, n_estimators=100;, score=-0.264 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, max_depth=1, n_estimators=100;, score=-0.272 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, max_depth=1, n_estimators=100;, score=-0.258 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, max_depth=1, n_estimators=150;, score=-0.231 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, max_depth=1, n_estimators=150;, score=-0.232 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, max_depth=1, n_estimators=150;, score=-0.231 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, max_depth=1, n_estimators=150;, score=-0.240 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, max_depth=1, n_estimators=150;, score=-0.227 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=-0.111 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=-0.122 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=-0.118 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=-0.126 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=-0.116 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, max_depth=3, n_estimators=100;, score=-0.087 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, max_depth=3, n_estimators=100;, score=-0.097 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, max_depth=3, n_estimators=100;, score=-0.098 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, max_depth=3, n_estimators=100;, score=-0.103 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, max_depth=3, n_estimators=100;, score=-0.094 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, max_depth=3, n_estimators=150;, score=-0.079 total time=   0.1s
# [CV 2/5] END learning_rate=0.1, max_depth=3, n_estimators=150;, score=-0.089 total time=   0.1s
# [CV 3/5] END learning_rate=0.1, max_depth=3, n_estimators=150;, score=-0.090 total time=   0.1s
# [CV 4/5] END learning_rate=0.1, max_depth=3, n_estimators=150;, score=-0.095 total time=   0.1s
# [CV 5/5] END learning_rate=0.1, max_depth=3, n_estimators=150;, score=-0.087 total time=   0.1s
# [CV 1/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=-0.077 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=-0.085 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=-0.084 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=-0.093 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=-0.083 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, max_depth=5, n_estimators=100;, score=-0.066 total time=   0.1s
# [CV 2/5] END learning_rate=0.1, max_depth=5, n_estimators=100;, score=-0.075 total time=   0.1s
# [CV 3/5] END learning_rate=0.1, max_depth=5, n_estimators=100;, score=-0.073 total time=   0.1s
# [CV 4/5] END learning_rate=0.1, max_depth=5, n_estimators=100;, score=-0.081 total time=   0.1s
# [CV 5/5] END learning_rate=0.1, max_depth=5, n_estimators=100;, score=-0.072 total time=   0.1s
# [CV 1/5] END learning_rate=0.1, max_depth=5, n_estimators=150;, score=-0.061 total time=   0.1s
# [CV 2/5] END learning_rate=0.1, max_depth=5, n_estimators=150;, score=-0.070 total time=   0.1s
# [CV 3/5] END learning_rate=0.1, max_depth=5, n_estimators=150;, score=-0.069 total time=   0.1s
# [CV 4/5] END learning_rate=0.1, max_depth=5, n_estimators=150;, score=-0.073 total time=   0.1s
# [CV 5/5] END learning_rate=0.1, max_depth=5, n_estimators=150;, score=-0.066 total time=   0.1s
# [CV 1/5] END learning_rate=0.1, max_depth=7, n_estimators=50;, score=-0.062 total time=   0.1s
# [CV 2/5] END learning_rate=0.1, max_depth=7, n_estimators=50;, score=-0.070 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, max_depth=7, n_estimators=50;, score=-0.067 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, max_depth=7, n_estimators=50;, score=-0.077 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, max_depth=7, n_estimators=50;, score=-0.066 total time=   0.1s
# [CV 1/5] END learning_rate=0.1, max_depth=7, n_estimators=100;, score=-0.053 total time=   0.1s
# [CV 2/5] END learning_rate=0.1, max_depth=7, n_estimators=100;, score=-0.061 total time=   0.1s
# [CV 3/5] END learning_rate=0.1, max_depth=7, n_estimators=100;, score=-0.060 total time=   0.1s
# [CV 4/5] END learning_rate=0.1, max_depth=7, n_estimators=100;, score=-0.064 total time=   0.1s
# [CV 5/5] END learning_rate=0.1, max_depth=7, n_estimators=100;, score=-0.056 total time=   0.1s
# [CV 1/5] END learning_rate=0.1, max_depth=7, n_estimators=150;, score=-0.049 total time=   0.2s
# [CV 2/5] END learning_rate=0.1, max_depth=7, n_estimators=150;, score=-0.053 total time=   0.2s
# [CV 3/5] END learning_rate=0.1, max_depth=7, n_estimators=150;, score=-0.053 total time=   0.2s
# [CV 4/5] END learning_rate=0.1, max_depth=7, n_estimators=150;, score=-0.052 total time=   0.2s
# [CV 5/5] END learning_rate=0.1, max_depth=7, n_estimators=150;, score=-0.050 total time=   0.2s
# [CV 1/5] END learning_rate=0.3, max_depth=1, n_estimators=50;, score=-0.224 total time=   0.0s
# [CV 2/5] END learning_rate=0.3, max_depth=1, n_estimators=50;, score=-0.225 total time=   0.0s
# [CV 3/5] END learning_rate=0.3, max_depth=1, n_estimators=50;, score=-0.223 total time=   0.0s
# [CV 4/5] END learning_rate=0.3, max_depth=1, n_estimators=50;, score=-0.233 total time=   0.0s
# [CV 5/5] END learning_rate=0.3, max_depth=1, n_estimators=50;, score=-0.219 total time=   0.0s
# [CV 1/5] END learning_rate=0.3, max_depth=1, n_estimators=100;, score=-0.174 total time=   0.0s
# [CV 2/5] END learning_rate=0.3, max_depth=1, n_estimators=100;, score=-0.174 total time=   0.0s
# [CV 3/5] END learning_rate=0.3, max_depth=1, n_estimators=100;, score=-0.174 total time=   0.0s
# [CV 4/5] END learning_rate=0.3, max_depth=1, n_estimators=100;, score=-0.181 total time=   0.0s
# [CV 5/5] END learning_rate=0.3, max_depth=1, n_estimators=100;, score=-0.171 total time=   0.0s
# [CV 1/5] END learning_rate=0.3, max_depth=1, n_estimators=150;, score=-0.150 total time=   0.0s
# [CV 2/5] END learning_rate=0.3, max_depth=1, n_estimators=150;, score=-0.151 total time=   0.0s
# [CV 3/5] END learning_rate=0.3, max_depth=1, n_estimators=150;, score=-0.152 total time=   0.0s
# [CV 4/5] END learning_rate=0.3, max_depth=1, n_estimators=150;, score=-0.158 total time=   0.0s
# [CV 5/5] END learning_rate=0.3, max_depth=1, n_estimators=150;, score=-0.149 total time=   0.0s
# [CV 1/5] END learning_rate=0.3, max_depth=3, n_estimators=50;, score=-0.076 total time=   0.0s
# [CV 2/5] END learning_rate=0.3, max_depth=3, n_estimators=50;, score=-0.088 total time=   0.0s
# [CV 3/5] END learning_rate=0.3, max_depth=3, n_estimators=50;, score=-0.088 total time=   0.0s
# [CV 4/5] END learning_rate=0.3, max_depth=3, n_estimators=50;, score=-0.092 total time=   0.0s
# [CV 5/5] END learning_rate=0.3, max_depth=3, n_estimators=50;, score=-0.087 total time=   0.0s
# [CV 1/5] END learning_rate=0.3, max_depth=3, n_estimators=100;, score=-0.068 total time=   0.0s
# [CV 2/5] END learning_rate=0.3, max_depth=3, n_estimators=100;, score=-0.077 total time=   0.0s
# [CV 3/5] END learning_rate=0.3, max_depth=3, n_estimators=100;, score=-0.079 total time=   0.0s
# [CV 4/5] END learning_rate=0.3, max_depth=3, n_estimators=100;, score=-0.081 total time=   0.0s
# [CV 5/5] END learning_rate=0.3, max_depth=3, n_estimators=100;, score=-0.075 total time=   0.0s
# [CV 1/5] END learning_rate=0.3, max_depth=3, n_estimators=150;, score=-0.064 total time=   0.1s
# [CV 2/5] END learning_rate=0.3, max_depth=3, n_estimators=150;, score=-0.071 total time=   0.1s
# [CV 3/5] END learning_rate=0.3, max_depth=3, n_estimators=150;, score=-0.075 total time=   0.1s
# [CV 4/5] END learning_rate=0.3, max_depth=3, n_estimators=150;, score=-0.073 total time=   0.1s
# [CV 5/5] END learning_rate=0.3, max_depth=3, n_estimators=150;, score=-0.069 total time=   0.1s
# [CV 1/5] END learning_rate=0.3, max_depth=5, n_estimators=50;, score=-0.060 total time=   0.0s
# [CV 2/5] END learning_rate=0.3, max_depth=5, n_estimators=50;, score=-0.068 total time=   0.0s
# [CV 3/5] END learning_rate=0.3, max_depth=5, n_estimators=50;, score=-0.067 total time=   0.0s
# [CV 4/5] END learning_rate=0.3, max_depth=5, n_estimators=50;, score=-0.072 total time=   0.0s
# [CV 5/5] END learning_rate=0.3, max_depth=5, n_estimators=50;, score=-0.064 total time=   0.0s
# [CV 1/5] END learning_rate=0.3, max_depth=5, n_estimators=100;, score=-0.053 total time=   0.1s
# [CV 2/5] END learning_rate=0.3, max_depth=5, n_estimators=100;, score=-0.052 total time=   0.1s
# [CV 3/5] END learning_rate=0.3, max_depth=5, n_estimators=100;, score=-0.059 total time=   0.1s
# [CV 4/5] END learning_rate=0.3, max_depth=5, n_estimators=100;, score=-0.053 total time=   0.1s
# [CV 5/5] END learning_rate=0.3, max_depth=5, n_estimators=100;, score=-0.052 total time=   0.1s
# [CV 1/5] END learning_rate=0.3, max_depth=5, n_estimators=150;, score=-0.050 total time=   0.1s
# [CV 2/5] END learning_rate=0.3, max_depth=5, n_estimators=150;, score=-0.048 total time=   0.1s
# [CV 3/5] END learning_rate=0.3, max_depth=5, n_estimators=150;, score=-0.054 total time=   0.1s
# [CV 4/5] END learning_rate=0.3, max_depth=5, n_estimators=150;, score=-0.047 total time=   0.1s
# [CV 5/5] END learning_rate=0.3, max_depth=5, n_estimators=150;, score=-0.048 total time=   0.1s
# [CV 1/5] END learning_rate=0.3, max_depth=7, n_estimators=50;, score=-0.051 total time=   0.0s
# [CV 2/5] END learning_rate=0.3, max_depth=7, n_estimators=50;, score=-0.052 total time=   0.0s
# [CV 3/5] END learning_rate=0.3, max_depth=7, n_estimators=50;, score=-0.054 total time=   0.0s
# [CV 4/5] END learning_rate=0.3, max_depth=7, n_estimators=50;, score=-0.052 total time=   0.0s
# [CV 5/5] END learning_rate=0.3, max_depth=7, n_estimators=50;, score=-0.050 total time=   0.0s
# [CV 1/5] END learning_rate=0.3, max_depth=7, n_estimators=100;, score=-0.049 total time=   0.1s
# [CV 2/5] END learning_rate=0.3, max_depth=7, n_estimators=100;, score=-0.045 total time=   0.1s
# [CV 3/5] END learning_rate=0.3, max_depth=7, n_estimators=100;, score=-0.050 total time=   0.1s
# [CV 4/5] END learning_rate=0.3, max_depth=7, n_estimators=100;, score=-0.040 total time=   0.1s
# [CV 5/5] END learning_rate=0.3, max_depth=7, n_estimators=100;, score=-0.046 total time=   0.1s
# [CV 1/5] END learning_rate=0.3, max_depth=7, n_estimators=150;, score=-0.051 total time=   0.2s
# [CV 2/5] END learning_rate=0.3, max_depth=7, n_estimators=150;, score=-0.046 total time=   0.2s
# [CV 3/5] END learning_rate=0.3, max_depth=7, n_estimators=150;, score=-0.050 total time=   0.1s
# [CV 4/5] END learning_rate=0.3, max_depth=7, n_estimators=150;, score=-0.040 total time=   0.2s
# [CV 5/5] END learning_rate=0.3, max_depth=7, n_estimators=150;, score=-0.047 total time=   0.2s
# [CV 1/5] END learning_rate=0.5, max_depth=1, n_estimators=50;, score=-0.179 total time=   0.0s
# [CV 2/5] END learning_rate=0.5, max_depth=1, n_estimators=50;, score=-0.179 total time=   0.0s
# [CV 3/5] END learning_rate=0.5, max_depth=1, n_estimators=50;, score=-0.179 total time=   0.0s
# [CV 4/5] END learning_rate=0.5, max_depth=1, n_estimators=50;, score=-0.188 total time=   0.0s
# [CV 5/5] END learning_rate=0.5, max_depth=1, n_estimators=50;, score=-0.176 total time=   0.0s
# [CV 1/5] END learning_rate=0.5, max_depth=1, n_estimators=100;, score=-0.140 total time=   0.0s
# [CV 2/5] END learning_rate=0.5, max_depth=1, n_estimators=100;, score=-0.143 total time=   0.0s
# [CV 3/5] END learning_rate=0.5, max_depth=1, n_estimators=100;, score=-0.144 total time=   0.0s
# [CV 4/5] END learning_rate=0.5, max_depth=1, n_estimators=100;, score=-0.150 total time=   0.0s
# [CV 5/5] END learning_rate=0.5, max_depth=1, n_estimators=100;, score=-0.141 total time=   0.0s
# [CV 1/5] END learning_rate=0.5, max_depth=1, n_estimators=150;, score=-0.128 total time=   0.0s
# [CV 2/5] END learning_rate=0.5, max_depth=1, n_estimators=150;, score=-0.130 total time=   0.0s
# [CV 3/5] END learning_rate=0.5, max_depth=1, n_estimators=150;, score=-0.134 total time=   0.0s
# [CV 4/5] END learning_rate=0.5, max_depth=1, n_estimators=150;, score=-0.140 total time=   0.0s
# [CV 5/5] END learning_rate=0.5, max_depth=1, n_estimators=150;, score=-0.131 total time=   0.0s
# [CV 1/5] END learning_rate=0.5, max_depth=3, n_estimators=50;, score=-0.071 total time=   0.0s
# [CV 2/5] END learning_rate=0.5, max_depth=3, n_estimators=50;, score=-0.081 total time=   0.0s
# [CV 3/5] END learning_rate=0.5, max_depth=3, n_estimators=50;, score=-0.081 total time=   0.0s
# [CV 4/5] END learning_rate=0.5, max_depth=3, n_estimators=50;, score=-0.085 total time=   0.0s
# [CV 5/5] END learning_rate=0.5, max_depth=3, n_estimators=50;, score=-0.077 total time=   0.0s
# [CV 1/5] END learning_rate=0.5, max_depth=3, n_estimators=100;, score=-0.066 total time=   0.0s
# [CV 2/5] END learning_rate=0.5, max_depth=3, n_estimators=100;, score=-0.071 total time=   0.0s
# [CV 3/5] END learning_rate=0.5, max_depth=3, n_estimators=100;, score=-0.071 total time=   0.0s
# [CV 4/5] END learning_rate=0.5, max_depth=3, n_estimators=100;, score=-0.072 total time=   0.0s
# [CV 5/5] END learning_rate=0.5, max_depth=3, n_estimators=100;, score=-0.067 total time=   0.0s
# [CV 1/5] END learning_rate=0.5, max_depth=3, n_estimators=150;, score=-0.063 total time=   0.1s
# [CV 2/5] END learning_rate=0.5, max_depth=3, n_estimators=150;, score=-0.063 total time=   0.1s
# [CV 3/5] END learning_rate=0.5, max_depth=3, n_estimators=150;, score=-0.067 total time=   0.1s
# [CV 4/5] END learning_rate=0.5, max_depth=3, n_estimators=150;, score=-0.065 total time=   0.1s
# [CV 5/5] END learning_rate=0.5, max_depth=3, n_estimators=150;, score=-0.058 total time=   0.1s
# [CV 1/5] END learning_rate=0.5, max_depth=5, n_estimators=50;, score=-0.055 total time=   0.1s
# [CV 2/5] END learning_rate=0.5, max_depth=5, n_estimators=50;, score=-0.056 total time=   0.0s
# [CV 3/5] END learning_rate=0.5, max_depth=5, n_estimators=50;, score=-0.059 total time=   0.0s
# [CV 4/5] END learning_rate=0.5, max_depth=5, n_estimators=50;, score=-0.055 total time=   0.0s
# [CV 5/5] END learning_rate=0.5, max_depth=5, n_estimators=50;, score=-0.057 total time=   0.0s
# [CV 1/5] END learning_rate=0.5, max_depth=5, n_estimators=100;, score=-0.052 total time=   0.1s
# [CV 2/5] END learning_rate=0.5, max_depth=5, n_estimators=100;, score=-0.051 total time=   0.1s
# [CV 3/5] END learning_rate=0.5, max_depth=5, n_estimators=100;, score=-0.056 total time=   0.1s
# [CV 4/5] END learning_rate=0.5, max_depth=5, n_estimators=100;, score=-0.045 total time=   0.1s
# [CV 5/5] END learning_rate=0.5, max_depth=5, n_estimators=100;, score=-0.050 total time=   0.1s
# [CV 1/5] END learning_rate=0.5, max_depth=5, n_estimators=150;, score=-0.053 total time=   0.1s
# [CV 2/5] END learning_rate=0.5, max_depth=5, n_estimators=150;, score=-0.051 total time=   0.1s
# [CV 3/5] END learning_rate=0.5, max_depth=5, n_estimators=150;, score=-0.057 total time=   0.1s
# [CV 4/5] END learning_rate=0.5, max_depth=5, n_estimators=150;, score=-0.043 total time=   0.1s
# [CV 5/5] END learning_rate=0.5, max_depth=5, n_estimators=150;, score=-0.051 total time=   0.1s
# [CV 1/5] END learning_rate=0.5, max_depth=7, n_estimators=50;, score=-0.050 total time=   0.0s
# [CV 2/5] END learning_rate=0.5, max_depth=7, n_estimators=50;, score=-0.050 total time=   0.0s
# [CV 3/5] END learning_rate=0.5, max_depth=7, n_estimators=50;, score=-0.050 total time=   0.0s
# [CV 4/5] END learning_rate=0.5, max_depth=7, n_estimators=50;, score=-0.045 total time=   0.0s
# [CV 5/5] END learning_rate=0.5, max_depth=7, n_estimators=50;, score=-0.047 total time=   0.0s
# [CV 1/5] END learning_rate=0.5, max_depth=7, n_estimators=100;, score=-0.052 total time=   0.1s
# [CV 2/5] END learning_rate=0.5, max_depth=7, n_estimators=100;, score=-0.049 total time=   0.1s
# [CV 3/5] END learning_rate=0.5, max_depth=7, n_estimators=100;, score=-0.055 total time=   0.1s
# [CV 4/5] END learning_rate=0.5, max_depth=7, n_estimators=100;, score=-0.043 total time=   0.1s
# [CV 5/5] END learning_rate=0.5, max_depth=7, n_estimators=100;, score=-0.049 total time=   0.1s
# [CV 1/5] END learning_rate=0.5, max_depth=7, n_estimators=150;, score=-0.057 total time=   0.1s
# [CV 2/5] END learning_rate=0.5, max_depth=7, n_estimators=150;, score=-0.053 total time=   0.2s
# [CV 3/5] END learning_rate=0.5, max_depth=7, n_estimators=150;, score=-0.058 total time=   0.1s
# [CV 4/5] END learning_rate=0.5, max_depth=7, n_estimators=150;, score=-0.045 total time=   0.2s
# [CV 5/5] END learning_rate=0.5, max_depth=7, n_estimators=150;, score=-0.052 total time=   0.2s
# {'learning_rate': 0.3, 'max_depth': 7, 'n_estimators': 100}
# -0.046194777318762995
