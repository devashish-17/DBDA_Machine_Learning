# %%
import pandas as pd
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold, KFold
from sklearn.metrics import accuracy_score, log_loss, classification_report
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import BaggingClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('bio_signal.csv')
df.head()
# Out:
#    id  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0   0   55         165          60       81.0             0.5
# 1   1   70         165          65       89.0             0.6
# 2   2   20         170          75       81.0             0.4
# 3   3   35         180          95      105.0             1.5
# 4   4   30         165          60       80.5             1.5
#
#    eyesight(right)  hearing(left)  hearing(right)  systolic  ...  HDL  LDL  \
# 0              0.6              1               1       135  ...   40   75
# 1              0.7              2               2       146  ...   57  126
# 2              0.5              1               1       118  ...   45   93
# 3              1.2              1               1       131  ...   38  102
# 4              1.0              1               1       121  ...   44   93
#
#    hemoglobin  Urine protein  serum creatinine  AST  ALT  Gtp  dental caries  \
# ...

# %%
X = df.drop('smoking', axis=1)
y = df['smoking']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=24)

# %%
ac = AdaBoostClassifier(random_state=24)
ac.fit(X_train, y_train)
y_pred = ac.predict(X_test)
print(accuracy_score(y_test, y_pred))

y_pred_prob = ac.predict_proba(X_test)[:,1]
print(log_loss(y_test, y_pred_prob))
# Out:
# 0.7692822906419406
# 0.6805842911315235

# %%
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=24)
ac = AdaBoostClassifier(random_state=24)

lr = LogisticRegression()
nb = GaussianNB()
dtc = DecisionTreeClassifier()

params = {
    'n_estimators': [25,50,75],
    'estimator': [lr, dtc, nb]
}
gcv = GridSearchCV(ac, param_grid=params, cv=kfold, verbose=3, scoring='neg_log_loss')
gcv.fit(X, y)
print(gcv.best_params_)
print(gcv.best_score_)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5] END estimator=LogisticRegression(), n_estimators=25;, score=-0.679 total time=  24.7s
# [CV 2/5] END estimator=LogisticRegression(), n_estimators=25;, score=-0.679 total time=  24.6s
# [CV 3/5] END estimator=LogisticRegression(), n_estimators=25;, score=-0.679 total time=  24.3s
# [CV 4/5] END estimator=LogisticRegression(), n_estimators=25;, score=-0.679 total time=  24.6s
# [CV 5/5] END estimator=LogisticRegression(), n_estimators=25;, score=-0.679 total time=  24.1s
# [CV 1/5] END estimator=LogisticRegression(), n_estimators=50;, score=-0.686 total time=  48.8s
# [CV 2/5] END estimator=LogisticRegression(), n_estimators=50;, score=-0.685 total time=  52.1s
# [CV 3/5] END estimator=LogisticRegression(), n_estimators=50;, score=-0.685 total time=  51.8s
# [CV 4/5] END estimator=LogisticRegression(), n_estimators=50;, score=-0.685 total time=  51.4s
# ...
